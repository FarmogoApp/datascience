# %% [markdown]
# Loading Data in Pandas DataFrame format
# Use nrows to limit data analise to get faster (but limited) results. If you wan all data put a huge value in this var.

# %%
import pandas as pd
from Util import loadJson,loadCsv,saveJson

nrows = -1 # work with all data take a long time

data1 = loadJson('P-DM280-measures.json','DM280',nrows);
data2 = loadCsv('P-BMP280-measures.csv','BMP280',nrows);

# %% [markdown]
# As we make an outer join we can view that some rows no has value on same time on each other.

# %%
data= data1.join(data2.set_index('time'), on='time', how='outer', sort=True )

# %%
data.describe()
# Out:
#              DM280        BMP280
# count     4.000000  1.422787e+06
# mean   1039.980000  1.015690e+03
# std       0.024495  1.011062e+01
# min    1039.950000  9.856200e+02
# 25%    1039.965000  1.008670e+03
# 50%    1039.985000  1.016970e+03
# 75%    1040.000000  1.022570e+03
# max    1040.000000  1.039050e+03

# %% [markdown]
# We can view graphically the mode of all sensors. We can check that sensor DM280 has very few data

# %%
data.plot.line(x = 'time',figsize=(20,10))
